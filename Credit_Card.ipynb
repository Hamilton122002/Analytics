# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cc.csv')

# %%
df
# Out:
#      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0        1         87073            100000                   2
# 1        2         38414             50000                   3
# 2        3         17341             50000                   7
# 3        4         40496             30000                   5
# 4        5         47437            100000                   6
# ..     ...           ...               ...                 ...
# 655    656         51108             99000                  10
# 656    657         60732             84000                  10
# 657    658         53834            145000                   8
# 658    659         80655            172000                  10
# 659    660         80150            167000                   9
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 0                    1                    1                 0
# 1                    0                   10                 9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sl_No                660 non-null    int64
#  1   Customer Key         660 non-null    int64
#  2   Avg_Credit_Limit     660 non-null    int64
#  3   Total_Credit_Cards   660 non-null    int64
#  4   Total_visits_bank    660 non-null    int64
#  5   Total_visits_online  660 non-null    int64
#  6   Total_calls_made     660 non-null    int64
# dtypes: int64(7)
# memory usage: 36.2 KB

# %%
df['Avg_Credit_Limit'].mean()
# Out:
# 34574.242424242424

# %%
df.drop(['Sl_No','Customer Key'],axis=1,inplace=True)

# %%
cc = df['Total_Credit_Cards'].value_counts()

# %%
plt.boxplot(x = 'Avg_Credit_Limit', data = df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.displot(x = 'Avg_Credit_Limit', data = df, aspect = 1.5, height = 6, kde=True)

# %%
visit_count = df['Total_visits_bank'].value_counts()

# %%
sns.histplot(x = 'Total_visits_bank', data = df)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.histplot(x = 'Total_visits_online', data = df)
# Out:
# <AxesSubplot:xlabel='Total_visits_online', ylabel='Count'>

# %%
plt.figure(figsize=(9,7))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
df.sort_values(by = 'Avg_Credit_Limit', ascending = False)
# Out:
#      Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 630            200000                  10                  0
# 650            195000                  10                  1
# 631            195000                   8                  0
# 632            187000                   7                  1
# 646            186000                   7                  0
# ..                ...                 ...                ...
# 62               5000                   1                  0
# 244              5000                   7                  3
# 124              5000                   2                  2
# 317              5000                   5                  5
# 9                3000                   4                  0
#
#      Total_visits_online  Total_calls_made
# 630                   13                 0
# 650                   12                 2
# 631                   15                 0
# 632                    7                 0
# ...
